# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithyasri-2516/Datascience-lab/blob/main/ex9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 '''

 Experiment Title
Model Serialization and Deployment using Flask/FastAPI as a REST API

🎯 Aim
To serialize a trained machine learning model and deploy it as a RESTful API using Flask or FastAPI, enabling external applications to access the model for real-time predictions.

📝 Description
In this experiment, a machine learning model is first trained and then serialized using model persistence techniques such as Joblib or Pickle. Model serialization allows the trained model to be saved to disk and reused without retraining.
The serialized model is then integrated into a web framework such as Flask or FastAPI to create a REST API. The API exposes endpoints that accept input data in JSON format, process the data using the loaded model, and return predictions as HTTP responses.
The experiment includes the following steps:


Training a machine learning model.


Saving (serializing) the trained model to a file.


Creating a REST API using Flask or FastAPI.


Loading the serialized model into the API.


Creating endpoints (e.g., /predict) for handling prediction requests.


Testing the API using tools such as Postman or curl.


This experiment demonstrates how machine learning models can be integrated into production environments, enabling scalable, real-time prediction services
for web and enterprise applications.'''
